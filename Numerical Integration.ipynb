# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint
# %matplotlib inline

# %%
def dT_dr(radius, temperature):
    return radius/temperature**(-5/2)

# %%
radii = np.linspace(1,5,100)
temp0 = 1.0  # the initial condition
temperatureRange = odeint(dT_dr, temp0, radii)
temperatureRange = np.array(temperatureRange).flatten()

# %%
plt.semilogy(radii, temperatureRange)

# %%
def dU_dx(U, radius):
    # U = [T,P]
    # Function returns [T' = P, P' = dP/dr]
    return [U[1], U[0]**(-5/2)*((-2/radius)*(U[0]**(5/2))*U[1]) - ((5/2)*(U[0]**(3/2))*(U[1]**2))]
U0 = [1.5e+04, 1]
radii = np.linspace(1, 30, 500)
Us = odeint(dU_dx, U0, radii)
temperatureSolution = Us[:,0]

# %%
plt.plot(radii, temperatureSolution)
